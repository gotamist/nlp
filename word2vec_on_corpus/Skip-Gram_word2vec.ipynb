# %% [markdown]
# # Skip-gram word2vec
#
# Continuous bag of words (CBOW) and Skip-gram are the two most common ways currently in use to train word2vec on a corpus.  Here, I use TensorFlow to implement the word2vec algorithm using the skip-gram architecture.  This will come in handy when dealing with things like machine translation.
#
# ## Some resources
#
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# There may be tens of thousands of words in a corpus. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a waste of computation.
#
# To solve this problem and greatly increase the efficiency of our networks, word embeddings are useful. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# /home/thojo/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then we can extract it.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)
# Out:
# Text8 Dataset: 31.4MB [01:14, 418kB/s]

# %%
if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that the data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer because we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. We're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# Every example is trained using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Documentation of the Tensorflow function to do this.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# Use Thushan Ganegedara's implementation here to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-13-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 50
batch_size = 2000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 1000 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 5000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/20Jan2019.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/50 Iteration: 1000 Avg. Training loss: 54.9707 0.2891 sec/batch
# Epoch 1/50 Iteration: 2000 Avg. Training loss: 49.7884 0.2873 sec/batch
# Epoch 2/50 Iteration: 3000 Avg. Training loss: 47.1324 0.1986 sec/batch
# Epoch 2/50 Iteration: 4000 Avg. Training loss: 45.9206 0.2845 sec/batch
# Epoch 3/50 Iteration: 5000 Avg. Training loss: 44.9182 0.1054 sec/batch
# Nearest to it: unconditionally, numbering, bow, underwater, grimm, device, mobygames, squeezed,
# Nearest to called: interglacial, mtu, chroniclers, comp, commercialize, dahlhaus, hydrophilic, egbert,
# Nearest to there: sample, stares, straddles, periodization, cerca, accredited, mspf, ecclesiastical,
# Nearest to three: zero, four, connexion, supplanting, est, thrill, reformer, ai,
# Nearest to were: promptly, aegisthus, cessation, hermits, principal, subsidence, marked, lisbon,
# Nearest to this: kerensky, illusion, enlarged, instincts, basel, positives, belt, resistances,
# Nearest to all: toscana, nyx, yousef, legally, dissonant, disparaged, wear, consultative,
# Nearest to over: eurasian, enduring, russian, bermuda, deliver, amusing, competition, sandy,
# Nearest to mean: infinity, banca, universe, prattica, bach, yauch, lais, orlogsflag,
# Nearest to shown: parkes, entail, reflective, radium, condemnations, levellers, hypothermia, spontaneity,
# Nearest to heavy: colorado, ridgway, topalov, domitian, imported, brainwashed, janusz, blackface,
# Nearest to account: mamah, tuvalu, liberate, yves, sheaves, compensate, bilinear, navis,
# Nearest to discovered: nerve, morant, sweetcorn, byr, netanya, wreck, pequod, jealous,
# Nearest to governor: flagship, riverlands, mentored, purportedly, minister, ambivalence, sdlp, gage,
# Nearest to except: transcendent, ulster, legalize, gcd, cachet, icftu, sages, asenath,
# Nearest to ice: semiempirical, kuleshov, denials, ionizing, debreu, directing, adamson, psychoanalysis,
# Epoch 3/50 Iteration: 6000 Avg. Training loss: 43.7778 0.2839 sec/batch
# Epoch 4/50 Iteration: 7000 Avg. Training loss: 43.2746 0.0172 sec/batch
# Epoch 4/50 Iteration: 8000 Avg. Training loss: 42.2868 0.2894 sec/batch
# Epoch 4/50 Iteration: 9000 Avg. Training loss: 42.2838 0.2912 sec/batch
# Epoch 5/50 Iteration: 10000 Avg. Training loss: 41.4816 0.2164 sec/batch
# Nearest to it: squeezed, unconditionally, numbering, annuities, imparts, casserole, invoked, saline,
# Nearest to called: mtu, comp, interglacial, chroniclers, hydrophilic, commercialize, dahlhaus, vertex,
# Nearest to there: cerca, periodization, straddles, timings, executes, migrated, sample, ornaments,
# Nearest to three: zero, four, five, six, one, two, luigi, honegger,
# Nearest to were: promptly, marked, sliding, shootings, parallel, pkn, installing, ethiopians,
# Nearest to this: illusion, known, orgasms, positives, syllabic, weems, electron, enlarged,
# Nearest to all: toscana, wear, legally, receiving, pants, mbox, thyself, disparaged,
# Nearest to over: enduring, bermuda, eurasian, teutonic, nine, amusing, competition, deliver,
# Nearest to mean: infinity, prattica, banca, bach, yauch, universe, marquises, eigenstates,
# Nearest to shown: parkes, condemnations, stardom, radium, n, bed, reflective, acrylic,
# Nearest to heavy: colorado, domitian, topalov, ridgway, scapa, romanisation, kassovitz, swing,
# Nearest to account: liberate, tuvalu, navis, sheaves, mamah, thousands, bulgogi, compensate,
# Nearest to discovered: morant, geological, nerve, he, wreck, byr, radiation, sweetcorn,
# Nearest to governor: sdlp, mentored, riverlands, minister, flagship, appointed, ange, caucasoid,
# Nearest to except: gcd, legalize, rounded, cachet, icftu, ulster, quetelet, equivalent,
# Nearest to ice: semiempirical, phosphates, ionizing, moist, covered, interior, readily, resident,
# Epoch 5/50 Iteration: 11000 Avg. Training loss: 41.2600 0.2888 sec/batch
# Epoch 6/50 Iteration: 12000 Avg. Training loss: 40.9174 0.1241 sec/batch
# Epoch 6/50 Iteration: 13000 Avg. Training loss: 40.4795 0.2874 sec/batch
# Epoch 7/50 Iteration: 14000 Avg. Training loss: 40.5588 0.0345 sec/batch
# Epoch 7/50 Iteration: 15000 Avg. Training loss: 39.9176 0.2894 sec/batch
# Nearest to it: imparts, numbering, the, is, squeezed, cetaceans, unconditionally, annuities,
# Nearest to called: mtu, interglacial, dahlhaus, comp, hydrophilic, factorize, usually, vertex,
# Nearest to there: cerca, have, timings, scrutinized, periodization, sample, extremities, size,
# Nearest to three: four, zero, five, six, two, one, seven, eight,
# Nearest to were: promptly, pkn, marked, installing, ethiopians, sixteenth, aafc, decius,
# Nearest to this: known, orgasms, illusion, since, pj, magisterial, syllabic, positives,
# Nearest to all: toscana, wear, pants, quaternions, mbox, organized, receiving, liminal,
# Nearest to over: nine, enduring, male, bermuda, est, deliver, teutonic, a,
# Nearest to mean: infinity, banca, prattica, wahhabism, yauch, oft, wfw, bach,
# Nearest to shown: ignore, parkes, stardom, n, condemnations, anaphylaxis, bed, flickering,
# Nearest to heavy: synthetics, domitian, scapa, colorado, topalov, romanisation, swing, phillippe,
# Nearest to account: liberate, navis, sheaves, zevi, tuvalu, explorer, demophon, compensate,
# Nearest to discovered: morant, early, seti, discoveries, expedition, marginalized, cmt, wreck,
# Nearest to governor: sdlp, riverlands, ange, mentored, minister, kabila, notify, flagship,
# Nearest to except: legalize, quetelet, rounded, gcd, slips, is, partement, equivalent,
# Nearest to ice: semiempirical, interior, austroasiatic, ionizing, yakko, iceberg, phantom, kuleshov,
# Epoch 7/50 Iteration: 16000 Avg. Training loss: 40.0543 0.2907 sec/batch
# Epoch 8/50 Iteration: 17000 Avg. Training loss: 39.6356 0.2337 sec/batch
# Epoch 8/50 Iteration: 18000 Avg. Training loss: 39.6108 0.2922 sec/batch
# Epoch 9/50 Iteration: 19000 Avg. Training loss: 39.5559 0.1424 sec/batch
# Epoch 9/50 Iteration: 20000 Avg. Training loss: 39.2815 0.2921 sec/batch
# Nearest to it: the, is, numbering, not, so, that, saline, squeezed,
# Nearest to called: mtu, comp, successively, interglacial, hydrophilic, dahlhaus, albemarle, gonzalez,
# Nearest to there: have, cerca, some, extremities, timings, are, residing, size,
# Nearest to three: four, zero, five, two, six, one, seven, eight,
# Nearest to were: promptly, sixteenth, these, widdecombe, moravians, installing, taman, privateers,
# Nearest to this: known, pj, orgasms, following, of, formally, cue, then,
# Nearest to all: toscana, organized, some, well, for, can, mdf, thyself,
# Nearest to over: nine, two, male, zero, enduring, a, teutonic, est,
# Nearest to mean: infinity, banca, wahhabism, prattica, lais, wfw, yauch, troubadors,
# Nearest to shown: ignore, stardom, parkes, flickering, subset, discover, n, anaphylaxis,
# Nearest to heavy: synthetics, domitian, scapa, romanisation, colorado, phenyl, phillippe, topalov,
# Nearest to account: zevi, navis, bulgogi, sheaves, liberate, accounts, explorer, tuvalu,
# Nearest to discovered: early, discoveries, discovery, marginalized, morant, he, washington, meteors,
# Nearest to governor: riverlands, sdlp, ange, minister, kabila, notify, mentored, racked,
# Nearest to except: partement, quetelet, slips, is, gcd, legalize, rounded, docteur,
# Nearest to ice: iceberg, semiempirical, austroasiatic, genevan, interior, yakko, ionizing, athletes,
# Epoch 10/50 Iteration: 21000 Avg. Training loss: 39.2871 0.0512 sec/batch
# Epoch 10/50 Iteration: 22000 Avg. Training loss: 39.0525 0.2907 sec/batch
# Epoch 10/50 Iteration: 23000 Avg. Training loss: 39.0118 0.2908 sec/batch
# Epoch 11/50 Iteration: 24000 Avg. Training loss: 38.7186 0.2477 sec/batch
# Epoch 11/50 Iteration: 25000 Avg. Training loss: 39.0050 0.2842 sec/batch
# Nearest to it: the, not, is, that, in, made, so, cetaceans,
# Nearest to called: mtu, gonzalez, comp, medley, melrose, kana, favorites, successively,
# Nearest to there: have, are, during, cerca, some, and, persons, no,
# Nearest to three: four, five, zero, six, two, one, nine, seven,
# Nearest to were: found, sixteenth, promptly, hundreds, these, moravians, made, although,
# Nearest to this: known, following, of, pj, since, then, orgasms, december,
# Nearest to all: for, organized, well, to, some, toscana, always, thyself,
# Nearest to over: nine, two, zero, male, a, since, with, geography,
# Nearest to mean: infinity, banca, predictive, lais, incur, wfw, prattica, wahhabism,
# Nearest to shown: ignore, stardom, discover, similar, parkes, subset, s, flickering,
# Nearest to heavy: synthetics, domitian, scapa, phenyl, romanisation, phillippe, portrayals, taiko,
# Nearest to account: zevi, accounts, navis, sheaves, eckert, compensate, bulgogi, bilinear,
# Nearest to discovered: early, discovery, washington, discoveries, investigated, he, cmt, marginalized,
# Nearest to governor: riverlands, sdlp, ange, minister, racked, yukon, locate, kabila,
# Nearest to except: slips, silly, quetelet, exceptions, partement, ulster, all, docteur,
# Nearest to ice: iceberg, semiempirical, austroasiatic, yakko, athletes, skates, mascheroni, guesses,
# Epoch 12/50 Iteration: 26000 Avg. Training loss: 38.7649 0.1592 sec/batch
# Epoch 12/50 Iteration: 27000 Avg. Training loss: 38.5342 0.2865 sec/batch
# Epoch 13/50 Iteration: 28000 Avg. Training loss: 38.6266 0.0687 sec/batch
# Epoch 13/50 Iteration: 29000 Avg. Training loss: 38.4792 0.2896 sec/batch
# Epoch 13/50 Iteration: 30000 Avg. Training loss: 38.5749 0.2881 sec/batch
# Nearest to it: the, not, is, that, in, when, was, to,
# Nearest to called: mtu, the, is, handles, for, mombasa, form, cercozoa,
# Nearest to there: are, have, some, and, with, no, during, only,
# Nearest to three: four, five, two, zero, six, one, nine, seven,
# Nearest to were: found, made, hundreds, the, some, could, these, although,
# Nearest to this: of, known, is, following, the, to, a, pj,
# Nearest to all: for, some, to, well, organized, of, except, be,
# Nearest to over: nine, zero, two, male, a, with, since, geography,
# Nearest to mean: banca, infinity, synonym, antecedent, wfw, troubadors, lais, mutt,
# Nearest to shown: ignore, s, similar, being, a, stardom, parkes, subset,
# Nearest to heavy: synthetics, domitian, phenyl, romanisation, scapa, respite, tikal, taiko,
# Nearest to account: zevi, accounts, excessively, bulgogi, eckert, navis, orkney, interlaced,
# Nearest to discovered: discovery, early, discoveries, investigated, washington, he, marginalized, bronze,
# Nearest to governor: riverlands, sdlp, minister, ange, racked, locate, figurehead, yukon,
# Nearest to except: all, slips, exceptions, is, quetelet, invariably, foreshadow, docteur,
# Nearest to ice: iceberg, athletes, semiempirical, austroasiatic, weren, yakko, properly, mascheroni,
# Epoch 14/50 Iteration: 31000 Avg. Training loss: 38.3202 0.2614 sec/batch
# Epoch 14/50 Iteration: 32000 Avg. Training loss: 38.4669 0.2900 sec/batch
# Epoch 15/50 Iteration: 33000 Avg. Training loss: 38.1871 0.1742 sec/batch
# Epoch 15/50 Iteration: 34000 Avg. Training loss: 38.1578 0.2840 sec/batch
# Epoch 16/50 Iteration: 35000 Avg. Training loss: 38.2302 0.0831 sec/batch
# Nearest to it: the, not, that, is, to, in, when, was,
# Nearest to called: the, is, for, mombasa, form, cercozoa, a, in,
# Nearest to there: have, are, some, and, only, no, also, but,
# Nearest to three: four, five, two, six, one, zero, nine, seven,
# Nearest to were: found, could, made, originally, was, the, some, early,
# Nearest to this: of, the, that, is, a, following, to, known,
# Nearest to all: for, some, to, of, except, organized, the, have,
# Nearest to over: two, nine, a, zero, male, with, geography, s,
# Nearest to mean: banca, synonym, lais, troubadors, wahhabism, matsya, infinity, wfw,
# Nearest to shown: being, s, ignore, similar, a, airing, commercials, indicates,
# Nearest to heavy: synthetics, domitian, respite, phenyl, colorado, romanisation, scapa, tikal,
# Nearest to account: accounts, zevi, eckert, excessively, chania, bulgogi, navis, interlaced,
# Nearest to discovered: discovery, discoveries, early, investigated, washington, he, excavating, was,
# Nearest to governor: riverlands, sdlp, minister, ange, locate, racked, figurehead, territory,
# Nearest to except: is, all, are, other, exceptions, invariably, slips, usual,
# Nearest to ice: iceberg, weren, austroasiatic, semiempirical, athletes, colder, properly, skates,
# Epoch 16/50 Iteration: 36000 Avg. Training loss: 37.9857 0.2872 sec/batch
# Epoch 16/50 Iteration: 37000 Avg. Training loss: 38.2022 0.2899 sec/batch
# Epoch 17/50 Iteration: 38000 Avg. Training loss: 37.9676 0.2834 sec/batch
# Epoch 17/50 Iteration: 39000 Avg. Training loss: 38.1508 0.2905 sec/batch
# Epoch 18/50 Iteration: 40000 Avg. Training loss: 37.8050 0.1920 sec/batch
# Nearest to it: the, not, is, to, that, in, when, was,
# Nearest to called: is, the, a, for, cercozoa, form, in, mombasa,
# Nearest to there: have, are, some, only, no, and, with, but,
# Nearest to three: four, five, two, six, zero, one, seven, nine,
# Nearest to were: was, found, did, could, made, hundreds, some, the,
# Nearest to this: of, is, that, be, to, the, a, can,
# Nearest to all: for, of, to, some, and, be, can, the,
# Nearest to over: two, zero, nine, a, with, one, s, five,
# Nearest to mean: banca, matsya, vedas, synonym, mutt, skewness, lais, incur,
# Nearest to shown: being, s, similar, ignore, a, is, commercials, confirm,
# Nearest to heavy: domitian, synthetics, respite, phenyl, colorado, nair, archer, hyman,
# Nearest to account: accounts, zevi, chania, eckert, interlaced, excessively, aggadic, ethiopians,
# Nearest to discovered: discovery, discoveries, investigated, washington, early, abundantly, excavating, origin,
# Nearest to governor: riverlands, ange, sdlp, racked, locate, minister, neotropical, forgent,
# Nearest to except: all, is, other, exceptions, are, of, invariably, usual,
# Nearest to ice: iceberg, weren, austroasiatic, colder, semiempirical, frozen, skates, sire,
# Epoch 18/50 Iteration: 41000 Avg. Training loss: 37.8651 0.2898 sec/batch
# Epoch 19/50 Iteration: 42000 Avg. Training loss: 37.9657 0.1012 sec/batch
# Epoch 19/50 Iteration: 43000 Avg. Training loss: 37.8876 0.2886 sec/batch
# Epoch 20/50 Iteration: 44000 Avg. Training loss: 37.9026 0.0104 sec/batch
# Epoch 20/50 Iteration: 45000 Avg. Training loss: 37.6656 0.2907 sec/batch
# Nearest to it: the, that, is, to, was, not, when, but,
# Nearest to called: is, a, the, in, for, by, form, terminology,
# Nearest to there: have, are, some, only, no, with, but, a,
# Nearest to three: four, five, two, six, zero, one, nine, eight,
# Nearest to were: was, found, hundreds, the, could, they, there, did,
# Nearest to this: of, be, is, that, the, can, to, an,
# Nearest to all: for, of, some, to, any, and, except, have,
# Nearest to over: zero, two, nine, a, male, one, since, five,
# Nearest to mean: synonym, banca, meanings, matsya, wfw, vedas, mathworld, mutt,
# Nearest to shown: similar, a, s, being, ignore, airing, is, confirm,
# Nearest to heavy: domitian, colorado, synthetics, respite, phenyl, archer, hyman, nair,
# Nearest to account: accounts, chania, zevi, eckert, interlaced, excessively, predestined, mismatch,
# Nearest to discovered: discovery, discoveries, investigated, excavating, washington, abundantly, discoverer, unknown,
# Nearest to governor: riverlands, minister, ange, taciturn, locate, racked, forgent, sdlp,
# Nearest to except: all, are, exceptions, other, is, of, vegetable, usual,
# Nearest to ice: iceberg, weren, skates, semiempirical, colder, guesses, austroasiatic, cream,
# Epoch 20/50 Iteration: 46000 Avg. Training loss: 37.7483 0.2900 sec/batch
# Epoch 21/50 Iteration: 47000 Avg. Training loss: 37.6051 0.2085 sec/batch
# Epoch 21/50 Iteration: 48000 Avg. Training loss: 37.6670 0.2881 sec/batch
# Epoch 22/50 Iteration: 49000 Avg. Training loss: 37.6422 0.1180 sec/batch
# Epoch 22/50 Iteration: 50000 Avg. Training loss: 37.5691 0.2891 sec/batch
# Nearest to it: the, that, is, not, to, was, but, has,
# Nearest to called: is, a, the, for, by, in, of, and,
# Nearest to there: have, are, only, and, more, no, than, but,
# Nearest to three: four, five, two, six, one, zero, seven, eight,
# Nearest to were: was, found, included, early, would, did, made, had,
# Nearest to this: of, that, be, the, is, not, a, an,
# Nearest to all: of, to, for, and, some, any, the, is,
# Nearest to over: zero, two, nine, a, since, have, s, one,
# Nearest to mean: synonym, meanings, banca, mathworld, vedas, wfw, mutt, sparknotes,
# Nearest to shown: similar, being, s, in, ignore, as, a, airing,
# Nearest to heavy: respite, phenyl, domitian, colorado, archer, synthetics, rhead, toshiba,
# Nearest to account: accounts, chania, zevi, excessively, predestined, hodder, constitute, turpin,
# Nearest to discovered: discovery, discoveries, investigated, excavating, early, uncovered, was, discoverer,
# Nearest to governor: minister, riverlands, territory, locate, administrator, legislature, opener, evacuation,
# Nearest to except: are, all, is, other, of, addition, exceptions, vegetable,
# Nearest to ice: iceberg, weren, skates, cream, semiempirical, colder, austroasiatic, frozen,
# Epoch 23/50 Iteration: 51000 Avg. Training loss: 37.6993 0.0267 sec/batch
# Epoch 23/50 Iteration: 52000 Avg. Training loss: 37.4204 0.2886 sec/batch
# Epoch 23/50 Iteration: 53000 Avg. Training loss: 37.6971 0.2890 sec/batch
# Epoch 24/50 Iteration: 54000 Avg. Training loss: 37.3890 0.2266 sec/batch
# Epoch 24/50 Iteration: 55000 Avg. Training loss: 37.5530 0.2897 sec/batch
# Nearest to it: the, that, is, was, to, not, but, has,
# Nearest to called: is, a, the, in, for, this, of, as,
# Nearest to there: have, are, only, and, but, least, be, although,
# Nearest to three: four, five, two, six, one, nine, zero, eight,
# Nearest to were: found, did, some, was, hundreds, the, early, included,
# Nearest to this: that, be, of, is, the, a, an, not,
# Nearest to all: for, of, to, except, some, any, and, be,
# Nearest to over: zero, a, with, two, s, and, of, have,
# Nearest to mean: synonym, meanings, mathworld, sparknotes, or, vegetables, matsya, banca,
# Nearest to shown: similar, being, been, airing, s, ignore, significance, in,
# Nearest to heavy: respite, colorado, reactor, domitian, toshiba, rhead, synthetics, nuclear,
# Nearest to account: accounts, chania, hodder, deliberate, zevi, cccc, turpin, eckert,
# Nearest to discovered: discovery, discoveries, investigated, unknown, remains, found, uncovered, bronze,
# Nearest to governor: minister, riverlands, legislature, state, territory, taciturn, opener, administrator,
# Nearest to except: all, are, exceptions, is, addition, other, means, of,
# Nearest to ice: iceberg, skates, weren, frozen, colder, semiempirical, sire, hockey,
# Epoch 25/50 Iteration: 56000 Avg. Training loss: 37.4983 0.1296 sec/batch
# Epoch 25/50 Iteration: 57000 Avg. Training loss: 37.3020 0.2876 sec/batch
# Epoch 26/50 Iteration: 58000 Avg. Training loss: 37.4935 0.0442 sec/batch
# Epoch 26/50 Iteration: 59000 Avg. Training loss: 37.2984 0.2875 sec/batch
# Epoch 26/50 Iteration: 60000 Avg. Training loss: 37.3997 0.2860 sec/batch
# Nearest to it: the, is, to, was, that, has, in, but,
# Nearest to called: is, a, the, in, and, for, this, by,
# Nearest to there: are, have, and, only, a, with, more, but,
# Nearest to three: four, five, two, six, one, zero, nine, seven,
# Nearest to were: did, was, found, they, had, could, hundreds, made,
# Nearest to this: that, be, of, the, not, a, an, is,
# Nearest to all: of, for, and, to, except, any, the, taking,
# Nearest to over: zero, nine, two, a, with, the, and, s,
# Nearest to mean: meanings, synonym, weighted, palmeiro, matsya, mathworld, wfw, appropriate,
# Nearest to shown: as, been, s, similar, being, in, airing, a,
# Nearest to heavy: respite, rhead, hyman, toshiba, colorado, synthetics, metal, reactor,
# Nearest to account: accounts, chania, hodder, zevi, eckert, unrecorded, turpin, deliberate,
# Nearest to discovered: discovery, discoveries, was, investigated, unknown, which, remains, found,
# Nearest to governor: riverlands, minister, state, legislature, seabirds, succubus, intersystems, territory,
# Nearest to except: all, addition, is, are, of, other, the, exceptions,
# Nearest to ice: iceberg, weren, frozen, colder, skates, hockey, semiempirical, cream,
# Epoch 27/50 Iteration: 61000 Avg. Training loss: 37.2504 0.2430 sec/batch
# Epoch 27/50 Iteration: 62000 Avg. Training loss: 37.4806 0.2894 sec/batch
# Epoch 28/50 Iteration: 63000 Avg. Training loss: 37.3319 0.1509 sec/batch
# Epoch 28/50 Iteration: 64000 Avg. Training loss: 37.1553 0.2890 sec/batch
# Epoch 29/50 Iteration: 65000 Avg. Training loss: 37.3696 0.0607 sec/batch
# Nearest to it: the, that, to, was, but, is, not, has,
# Nearest to called: is, the, a, in, of, into, by, and,
# Nearest to there: are, have, only, least, some, but, no, other,
# Nearest to three: four, five, two, six, one, seven, eight, zero,
# Nearest to were: they, the, did, but, some, could, found, was,
# Nearest to this: that, be, a, of, the, an, is, to,
# Nearest to all: of, to, for, any, can, some, and, except,
# Nearest to over: zero, with, a, at, two, under, have, s,
# Nearest to mean: meanings, palmeiro, appropriate, impose, synonym, matsya, mathworld, refers,
# Nearest to shown: been, similar, in, a, airing, s, significance, being,
# Nearest to heavy: respite, rhead, metal, hyman, reactor, toshiba, tikal, bnd,
# Nearest to account: accounts, chania, hodder, zevi, unrecorded, constitute, meant, turpin,
# Nearest to discovered: discovery, discoveries, remains, found, which, investigated, unknown, was,
# Nearest to governor: riverlands, minister, state, legislature, territory, interests, resigned, intersystems,
# Nearest to except: addition, all, is, of, rather, means, are, certain,
# Nearest to ice: iceberg, colder, weren, frozen, skates, cream, sire, semiempirical,
# Epoch 29/50 Iteration: 66000 Avg. Training loss: 37.0503 0.2882 sec/batch
# Epoch 29/50 Iteration: 67000 Avg. Training loss: 37.2156 0.2870 sec/batch
# Epoch 30/50 Iteration: 68000 Avg. Training loss: 37.0005 0.2590 sec/batch
# Epoch 30/50 Iteration: 69000 Avg. Training loss: 37.3531 0.2880 sec/batch
# Epoch 31/50 Iteration: 70000 Avg. Training loss: 37.0703 0.1679 sec/batch
# Nearest to it: to, the, was, is, that, but, in, of,
# Nearest to called: a, is, the, in, of, by, also, and,
# Nearest to there: have, are, only, with, more, and, least, no,
# Nearest to three: four, five, two, six, one, seven, zero, nine,
# Nearest to were: was, the, in, some, had, could, they, to,
# Nearest to this: that, be, of, a, the, an, not, is,
# Nearest to all: of, to, for, can, any, and, a, have,
# Nearest to over: zero, nine, two, with, one, five, a, at,
# Nearest to mean: meanings, appropriate, portmanteau, weighted, skewness, matsya, palmeiro, synonym,
# Nearest to shown: being, similar, s, been, airing, a, significance, featuring,
# Nearest to heavy: metal, rhead, respite, torpedo, phenyl, bnd, hyman, such,
# Nearest to account: accounts, chania, hodder, constitute, unrecorded, infects, identifying, deliberate,
# Nearest to discovered: discovery, discoveries, found, remains, investigated, was, which, uncovered,
# Nearest to governor: state, riverlands, cabinet, minister, legislature, interests, resigned, ange,
# Nearest to except: addition, is, all, of, are, certain, exceptions, unless,
# Nearest to ice: iceberg, weren, colder, frozen, cream, austroasiatic, skates, sire,
# Epoch 31/50 Iteration: 71000 Avg. Training loss: 37.1545 0.2909 sec/batch
# Epoch 32/50 Iteration: 72000 Avg. Training loss: 37.1742 0.0757 sec/batch
# Epoch 32/50 Iteration: 73000 Avg. Training loss: 36.9650 0.2887 sec/batch
# Epoch 32/50 Iteration: 74000 Avg. Training loss: 37.1648 0.2900 sec/batch
# Epoch 33/50 Iteration: 75000 Avg. Training loss: 36.9922 0.2737 sec/batch
# Nearest to it: to, that, the, was, is, but, not, which,
# Nearest to called: is, a, the, in, of, and, also, an,
# Nearest to there: are, have, only, more, some, least, no, can,
# Nearest to three: four, five, two, six, one, zero, nine, eight,
# Nearest to were: could, some, found, they, originally, was, had, did,
# Nearest to this: the, of, is, be, an, that, a, to,
# Nearest to all: of, to, for, the, any, and, some, more,
# Nearest to over: zero, two, nine, a, s, the, one, three,
# Nearest to mean: appropriate, meanings, weighted, portmanteau, palmeiro, matsya, skewness, refers,
# Nearest to shown: airing, similar, been, being, fact, s, appears, significance,
# Nearest to heavy: metal, phenyl, exo, bnd, combining, lobbying, suited, such,
# Nearest to account: accounts, chania, hodder, identifying, deliberate, unrecorded, figures, reactive,
# Nearest to discovered: discovery, discoveries, found, remains, investigated, unknown, ribozymes, manoel,
# Nearest to governor: state, riverlands, ange, resigned, minister, legislature, territory, cyclopaedia,
# Nearest to except: addition, all, of, unless, are, other, rather, also,
# Nearest to ice: iceberg, colder, frozen, weren, skates, cream, glacial, cube,
# Epoch 33/50 Iteration: 76000 Avg. Training loss: 37.1812 0.2875 sec/batch
# Epoch 34/50 Iteration: 77000 Avg. Training loss: 36.9955 0.1852 sec/batch
# Epoch 34/50 Iteration: 78000 Avg. Training loss: 37.0438 0.2908 sec/batch
# Epoch 35/50 Iteration: 79000 Avg. Training loss: 37.0778 0.0939 sec/batch
# Epoch 35/50 Iteration: 80000 Avg. Training loss: 36.8996 0.2879 sec/batch
# Nearest to it: that, the, to, was, is, has, never, an,
# Nearest to called: is, the, in, of, a, by, and, also,
# Nearest to there: have, are, only, can, with, and, least, be,
# Nearest to three: four, five, two, one, six, eight, nine, seven,
# Nearest to were: found, had, was, the, in, and, included, that,
# Nearest to this: of, that, be, the, an, a, such, is,
# Nearest to all: of, for, to, any, and, the, this, be,
# Nearest to over: zero, nine, s, two, a, since, one, have,
# Nearest to mean: meanings, weighted, appropriate, portmanteau, skewness, palmeiro, wfw, impose,
# Nearest to shown: been, s, similar, airing, fact, being, significance, in,
# Nearest to heavy: such, phenyl, torpedo, isotopes, heaviest, metal, massive, dreadnought,
# Nearest to account: accounts, chania, hodder, meant, unrecorded, iban, maelstrom, turpin,
# Nearest to discovered: discovery, discoveries, found, remains, unknown, investigated, pelts, theravada,
# Nearest to governor: resigned, riverlands, legislature, state, newly, minister, territory, appointed,
# Nearest to except: addition, all, unless, for, of, is, any, are,
# Nearest to ice: iceberg, weren, colder, frozen, skates, cream, glacial, cube,
# Epoch 36/50 Iteration: 81000 Avg. Training loss: 37.1210 0.0032 sec/batch
# Epoch 36/50 Iteration: 82000 Avg. Training loss: 36.8828 0.2909 sec/batch
# Epoch 36/50 Iteration: 83000 Avg. Training loss: 37.0546 0.2904 sec/batch
# Epoch 37/50 Iteration: 84000 Avg. Training loss: 36.8454 0.2033 sec/batch
# Epoch 37/50 Iteration: 85000 Avg. Training loss: 36.9136 0.2914 sec/batch
# Nearest to it: that, the, is, to, an, not, was, which,
# Nearest to called: a, in, is, the, by, of, an, also,
# Nearest to there: have, are, only, more, a, with, other, although,
# Nearest to three: four, five, six, two, one, eight, seven, nine,
# Nearest to were: was, survived, found, in, the, included, had, they,
# Nearest to this: that, of, the, be, a, an, to, is,
# Nearest to all: of, to, for, and, any, be, this, there,
# Nearest to over: and, two, at, zero, a, of, one, with,
# Nearest to mean: meanings, portmanteau, weighted, appropriate, synonym, over, the, orellana,
# Nearest to shown: been, similar, airing, a, appears, fact, being, the,
# Nearest to heavy: metal, reactor, nuclear, rhead, rain, phenyl, bnd, isotopes,
# Nearest to account: accounts, chania, iban, hodder, summarized, maelstrom, unrecorded, bank,
# Nearest to discovered: discovery, discoveries, remains, found, investigated, was, unknown, which,
# Nearest to governor: minister, legislature, resigned, appointed, state, riverlands, cabinet, elected,
# Nearest to except: addition, all, are, even, other, means, is, rather,
# Nearest to ice: colder, iceberg, frozen, weren, skates, cream, glacial, austroasiatic,
# Epoch 38/50 Iteration: 86000 Avg. Training loss: 36.9894 0.1114 sec/batch
# Epoch 38/50 Iteration: 87000 Avg. Training loss: 36.7934 0.2922 sec/batch
# Epoch 39/50 Iteration: 88000 Avg. Training loss: 36.9709 0.0204 sec/batch
# Epoch 39/50 Iteration: 89000 Avg. Training loss: 36.8043 0.2910 sec/batch
# Epoch 39/50 Iteration: 90000 Avg. Training loss: 36.9401 0.2931 sec/batch
# Nearest to it: the, to, is, has, that, was, in, not,
# Nearest to called: the, in, is, a, of, as, by, also,
# Nearest to there: are, have, with, only, more, be, a, the,
# Nearest to three: five, four, two, six, one, zero, seven, nine,
# Nearest to were: had, some, was, survived, they, included, did, as,
# Nearest to this: be, that, of, the, to, an, such, a,
# Nearest to all: of, for, to, and, the, any, can, be,
# Nearest to over: zero, two, and, one, five, with, have, in,
# Nearest to mean: meanings, appropriate, portmanteau, weighted, service, the, orellana, impose,
# Nearest to shown: been, airing, in, similar, fact, s, a, the,
# Nearest to heavy: metal, isotopes, lobbying, respite, reactor, grindcore, rain, such,
# Nearest to account: accounts, chania, iban, deliberate, bbbb, identifying, cccc, maelstrom,
# Nearest to discovered: discovery, discoveries, remains, was, found, investigated, somewhat, which,
# Nearest to governor: minister, legislature, resigned, state, senate, appointed, riverlands, territory,
# Nearest to except: all, addition, certain, of, the, virtually, other, even,
# Nearest to ice: iceberg, frozen, colder, mayfield, weren, cube, cream, skates,
# Epoch 40/50 Iteration: 91000 Avg. Training loss: 36.7219 0.2193 sec/batch
# Epoch 40/50 Iteration: 92000 Avg. Training loss: 36.9327 0.2917 sec/batch
# Epoch 41/50 Iteration: 93000 Avg. Training loss: 36.8761 0.1292 sec/batch
# Epoch 41/50 Iteration: 94000 Avg. Training loss: 36.8281 0.2888 sec/batch
# Epoch 42/50 Iteration: 95000 Avg. Training loss: 36.8985 0.0368 sec/batch
# Nearest to it: to, the, that, has, was, is, not, in,
# Nearest to called: is, in, a, the, of, by, and, itself,
# Nearest to there: are, have, least, and, with, that, all, but,
# Nearest to three: four, five, two, one, six, eight, zero, seven,
# Nearest to were: was, the, had, could, some, would, as, found,
# Nearest to this: that, to, the, be, a, of, an, but,
# Nearest to all: of, to, for, any, can, there, the, except,
# Nearest to over: zero, with, and, have, two, at, s, has,
# Nearest to mean: meanings, appropriate, weighted, portmanteau, mathworld, service, arithmetic, refers,
# Nearest to shown: s, airing, been, in, a, partially, is, has,
# Nearest to heavy: metal, reactor, wilful, massive, bnd, nair, synthesized, isotopes,
# Nearest to account: accounts, chania, iban, deliberate, interbreeding, summarized, bbbb, maelstrom,
# Nearest to discovered: discovery, discoveries, remains, found, which, was, in, investigated,
# Nearest to governor: minister, resigned, legislature, appointed, lieutenant, appoint, cabinet, senate,
# Nearest to except: all, addition, of, certain, most, even, other, can,
# Nearest to ice: iceberg, mayfield, frozen, hockey, glacial, austroasiatic, weren, colder,
# Epoch 42/50 Iteration: 96000 Avg. Training loss: 36.7336 0.2902 sec/batch
# Epoch 42/50 Iteration: 97000 Avg. Training loss: 36.8952 0.2902 sec/batch
# Epoch 43/50 Iteration: 98000 Avg. Training loss: 36.6811 0.2375 sec/batch
# Epoch 43/50 Iteration: 99000 Avg. Training loss: 36.8792 0.2912 sec/batch
# Epoch 44/50 Iteration: 100000 Avg. Training loss: 36.7416 0.1464 sec/batch
# Nearest to it: the, to, that, was, not, is, in, as,
# Nearest to called: is, a, the, in, of, as, by, and,
# Nearest to there: have, are, only, but, that, least, more, no,
# Nearest to three: four, five, two, six, one, nine, seven, eight,
# Nearest to were: had, was, and, the, as, some, in, early,
# Nearest to this: that, be, an, the, to, of, a, is,
# Nearest to all: of, to, for, and, the, any, only, in,
# Nearest to over: zero, have, at, two, with, nine, five, since,
# Nearest to mean: appropriate, meanings, portmanteau, term, weighted, orellana, skewness, or,
# Nearest to shown: been, airing, episode, s, being, appears, in, significance,
# Nearest to heavy: metal, carried, tzow, massive, wilful, bnd, synthesized, heaviest,
# Nearest to account: accounts, chania, iban, chapters, unrecorded, discrepancy, payments, cccc,
# Nearest to discovered: discovery, discoveries, found, remains, uncovered, which, exhibited, discover,
# Nearest to governor: resigned, minister, legislature, appointed, appoint, hammer, senate, cabinet,
# Nearest to except: addition, all, only, certain, thus, virtually, vegetable, be,
# Nearest to ice: iceberg, frozen, mayfield, hockey, austroasiatic, glacial, colder, cube,
# Epoch 44/50 Iteration: 101000 Avg. Training loss: 36.6411 0.2904 sec/batch
# Epoch 45/50 Iteration: 102000 Avg. Training loss: 36.8386 0.0542 sec/batch
# Epoch 45/50 Iteration: 103000 Avg. Training loss: 36.6742 0.2921 sec/batch
# Epoch 45/50 Iteration: 104000 Avg. Training loss: 36.7523 0.2917 sec/batch
# Epoch 46/50 Iteration: 105000 Avg. Training loss: 36.5114 0.2543 sec/batch
# Nearest to it: to, that, was, is, the, not, has, but,
# Nearest to called: a, the, is, in, of, an, as, by,
# Nearest to there: are, have, only, more, a, with, least, but,
# Nearest to three: four, five, two, one, six, eight, seven, zero,
# Nearest to were: some, was, had, could, they, there, previously, have,
# Nearest to this: that, is, be, of, to, a, the, such,
# Nearest to all: of, to, any, for, and, be, can, such,
# Nearest to over: zero, have, nine, two, one, five, s, three,
# Nearest to mean: appropriate, meanings, portmanteau, weighted, refers, is, term, mathworld,
# Nearest to shown: been, fact, airing, s, associated, partially, in, a,
# Nearest to heavy: metal, reactor, massive, tzow, lobbying, carried, such, sabian,
# Nearest to account: accounts, chania, iban, summarized, penniless, cccc, accurate, unrecorded,
# Nearest to discovered: discovery, discoveries, found, remains, investigated, unknown, was, analyzed,
# Nearest to governor: minister, hammer, resigned, legislature, appoint, appointed, state, senate,
# Nearest to except: addition, all, for, unless, to, them, even, of,
# Nearest to ice: frozen, iceberg, mayfield, hockey, cream, cube, colder, glacial,
# Epoch 46/50 Iteration: 106000 Avg. Training loss: 36.8622 0.2910 sec/batch
# Epoch 47/50 Iteration: 107000 Avg. Training loss: 36.6719 0.1623 sec/batch
# Epoch 47/50 Iteration: 108000 Avg. Training loss: 36.6463 0.2910 sec/batch
# Epoch 48/50 Iteration: 109000 Avg. Training loss: 36.7960 0.0711 sec/batch
# Epoch 48/50 Iteration: 110000 Avg. Training loss: 36.6028 0.2927 sec/batch
# Nearest to it: the, is, that, to, was, has, not, an,
# Nearest to called: a, is, the, in, also, of, an, as,
# Nearest to there: have, are, only, with, more, all, were, can,
# Nearest to three: four, five, two, one, six, eight, seven, zero,
# Nearest to were: was, some, and, had, there, found, included, the,
# Nearest to this: is, of, to, be, that, the, not, an,
# Nearest to all: of, to, for, any, and, be, the, some,
# Nearest to over: have, zero, two, in, a, an, with, since,
# Nearest to mean: appropriate, portmanteau, weighted, meanings, term, madelyne, refers, connotation,
# Nearest to shown: been, s, fact, in, airing, has, a, however,
# Nearest to heavy: metal, reactor, such, wilful, phenyl, grindcore, heaviest, synthesized,
# Nearest to account: accounts, iban, chania, summarized, accurate, bbbb, cccc, meant,
# Nearest to discovered: discovery, discoveries, found, remains, investigated, was, uncovered, rare,
# Nearest to governor: senate, minister, legislature, lieutenant, republican, appointed, legislatures, appoint,
# Nearest to except: addition, all, for, any, are, to, is, other,
# Nearest to ice: frozen, iceberg, mayfield, hockey, cream, skates, colder, austroasiatic,
# Epoch 48/50 Iteration: 111000 Avg. Training loss: 36.7237 0.2933 sec/batch
# Epoch 49/50 Iteration: 112000 Avg. Training loss: 36.5784 0.2691 sec/batch
# Epoch 49/50 Iteration: 113000 Avg. Training loss: 36.7806 0.2918 sec/batch
# Epoch 50/50 Iteration: 114000 Avg. Training loss: 36.4964 0.1793 sec/batch
# Epoch 50/50 Iteration: 115000 Avg. Training loss: 36.5504 0.2906 sec/batch
# Nearest to it: the, is, was, that, to, in, an, but,
# Nearest to called: a, is, in, the, of, also, as, that,
# Nearest to there: are, only, have, and, but, other, with, a,
# Nearest to three: four, two, five, six, seven, one, eight, nine,
# Nearest to were: had, found, was, some, in, almost, there, and,
# Nearest to this: that, of, be, the, to, even, is, which,
# Nearest to all: of, to, for, any, and, have, three, is,
# Nearest to over: zero, have, nine, two, since, s, with, all,
# Nearest to mean: appropriate, weighted, portmanteau, meanings, skewness, sparknotes, harmonic, reciprocal,
# Nearest to shown: been, s, a, as, similar, however, partially, the,
# Nearest to heavy: metal, reactor, isotopes, such, paces, phenyl, synthesized, grindcore,
# Nearest to account: accounts, chania, iban, bbbb, another, cccc, identification, summarized,
# Nearest to discovered: discovery, found, discoveries, remains, was, reached, recently, unknown,
# Nearest to governor: minister, appointed, appoint, resigned, senate, state, elected, republican,
# Nearest to except: addition, virtually, for, are, even, of, to, other,
# Nearest to ice: iceberg, frozen, mayfield, colder, cream, glacial, glacier, skates,

# %% [markdown]
# Restore the trained network if needed:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/20Jan2019.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. [This post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) explains more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
